# %%
import pandas as pd

# %%
# %ls
# Out:
# Gruntfile.js    Untitled.ipynb  d3/             package.json
# Procfile        app.js          node_modules/   public/
# README.md       bleach9802.csv  npm-debug.log   views/

# %%
bleach = pd.read_csv('bleach9802.csv')

# %%
bleach
# Out:
#          rfid subid                                        name        long  \
# 0     10325.0     S                                 North Ledge  142.740000
# 1     10327.0     S                                 South Ledge  142.730000
# 2     10336.0     S                                 Wyborn Reef  142.760000
# 3     10338.0     S                                  Womer Reef  142.980000
# 4     10340.0     S                          Turtle Island Reef  142.700000
# 5     11001.0     S                                 Arnold Reef  142.990000
# 6     11008.0     S                                    U/N Reef  142.820000
# 7     11009.0     S                           Bushy Island Reef  142.870000
# 8     11010.0     S                      Cairncross Islets Reef  142.930000
# 9     11013.0     S                          Halfway Islet Reef  142.970000
# 10    11025.0     S                                    U/N Reef  143.090000
# ...

# %%
bleach1998 = bleach[bleach.year ==1998]
bleach2002 = bleach[bleach.year ==2002]

# %%
bleach1998.to_json('bleach1998.json',orient='records')
bleach2002.to_json('bleach2002.json',orient='records')
